# %% [markdown]
# # Computational Fluid Dynamics final project - Lid-driven cavity data analysis (OpenFOAM)
#
# ## Student's Info
#
# | Name | Surname | Student ID | UniTs email | Personal email | Master course |
# |:---:|:---:|:---:|:---:|:---:|:---:|
# | Piero | Zappi | SM3600004 | `piero.zappi@studenti.units.it` | `piero.z.2001@gmail.com` | SDIC |
#
# ## Introduction
#
# In this notebook we will analyze the data obtained from the simulation of the lid-driven cavity flow. The simulation was performed using the OpenFOAM software and the data was collected in the form of a CSV file. The data consists of the velocity profile of the fluid. The goal is to compare the simulation data with the results of Ghia et al. for $Re=100$.

# %%
# Import the necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Import the csv file with the data from the simulation
data_u = pd.read_csv('u_OpenFoam.csv')
data_v = pd.read_csv('v_OpenFoam.csv')

# Extract the u velocity along the vertical line at x = 0.5
u_component_vertical = data_u.loc[data_u['Points:0'] == 0.5, ['Points:1', 'U:0']]

# Extract the v velocity along the horizontal line at y = 0.5
v_component_horizontal = data_v.loc[data_v['Points:1'] == 0.5, ['Points:0', 'U:1']]

# Create dataframes with the data of Ghia et al.
y_ghia = np.array([0.0000, 0.0547, 0.0625, 0.0703, 0.1016, 0.1719, 0.2813, 0.4531, 0.5000, 0.6172, 0.7344, 0.8516, 0.9531, 0.9609, 0.9688, 0.9766, 1.0000])
u_ghia = np.array([0.00000, -0.03371, -0.04192, -0.04775, -0.06434, -0.10150, -0.15662, -0.21090, -0.20581, -0.13641, 0.00332, 0.23151, 0.68717, 0.73722, 0.78871, 0.84123, 1.00000])
ghia_data_u = pd.DataFrame({'y': y_ghia, 'u': u_ghia})

x_ghia = np.array([0.0000, 0.0625, 0.0703, 0.0781, 0.0938, 0.1563, 0.2266, 0.2344, 0.5000, 0.8047, 0.8594, 0.9063, 0.9453, 0.9531, 0.9609, 0.9688, 1.0000])
v_ghia = np.array([0.00000, 0.09233, 0.10091, 0.10890, 0.12317, 0.16077, 0.17507, 0.17527, 0.05454, -0.24533, -0.22445, -0.16914, -0.10313, -0.08864, -0.07391, -0.05906, 0.00000])
ghia_data_v = pd.DataFrame({'x': x_ghia, 'v': v_ghia})

# Plot the data
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.plot(u_component_vertical['Points:1'], u_component_vertical['U:0'], 'b-', linewidth=2, label='Simulation data')
plt.plot(ghia_data_u['y'], ghia_data_u['u'], 'go', markersize=8, label='Ghia et al.')
plt.xlabel('y', fontsize=14)
plt.ylabel('u velocity', fontsize=14)
plt.title('u velocity along the vertical line at x = 0.5', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)
plt.show()

plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 2)
plt.plot(v_component_horizontal['Points:0'], v_component_horizontal['U:1'], 'b-', linewidth=2, label='Simulation data')
plt.plot(ghia_data_v['x'], ghia_data_v['v'], 'go', markersize=8, label='Ghia et al.')
plt.xlabel('x', fontsize=14)
plt.ylabel('v velocity', fontsize=14)
plt.title('v velocity along the horizontal line at y = 0.5', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)
plt.show()
